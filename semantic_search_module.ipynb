# %% [markdown]
# <a href="https://colab.research.google.com/github/jayinc/LLMs4Production/blob/main/semantic_search_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m spacy download en_core_web_sm
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip install openai==0.27.7
# Out:
# 2023-11-16 22:47:51.563200: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 22:47:51.563268: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 22:47:51.563309: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 22:47:53.266156: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 30.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.14.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting openai==0.27.7
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.27.7) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.7) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.27.7) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.7) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.7) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.7) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.7) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.7) (1.3.1)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.3.2
#     Uninstalling openai-1.3.2:
#       Successfully uninstalled openai-1.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.27.7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (4.3.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio) (0.104.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.7.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.7.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.9.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.5.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.24.0.post1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio) (11.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.14.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (13.6.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.0.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)

# %%
# !pip install -U sentence-transformers rank_bm25
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
import json
import pandas as pd
import time
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest
import nltk
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util
# import tiktoken
from openai.embeddings_utils import get_embedding, cosine_similarity

# %% [markdown]
# Read the data for Paris Hotels

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/hamzafarooq/maven-mlsystem-design-cohort-1/main/data/paris_02_11_23.csv')

# %%
df.shape
# Out:
# (28694, 18)

# %%
df.name.value_counts()
# Out:
# Hotel d'Angleterre, Saint Germain des Pres              960
# InterContinental Paris - Le Grand                       800
# Hotel Marceau Champs Elysees                            800
# Sonder Atala Champs-Élysées                             800
# Hotel Dauphine Saint Germain                            800
#                                                        ...
# Hotel B55                                                94
# Les Jardins du Faubourg                                  78
# Ibis Styles Paris Meteor Avenue de la Porte d'Italie     62
# Hotel Maxim Folies                                       54
# Mama Shelter Paris West                                  40
# Name: name, Length: 156, dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.to_csv('/content/drive/MyDrive/Semantic_Search/paris_02_11_23.csv',index=False)

# %%
df.shape
# Out:
# (11990, 18)

# %%
df.name.value_counts()
# Out:
# InterContinental Paris - Le Grand                       80
# Okko Hotels Paris Porte de Versailles                   80
# Citadines Montmartre Paris                              80
# Hotel Montfleuri                                        80
# Hotel Cayre                                             80
#                                                         ..
# Seven Hotel Paris                                       32
# Ibis Styles Paris Meteor Avenue de la Porte d'Italie    31
# Hotel Du Sentier                                        28
# Hotel Maxim Folies                                      27
# Mama Shelter Paris West                                 20
# Name: name, Length: 156, dtype: int64

# %%
df.head()
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
#
#                           author_id author_name author_username  \
# 0  E488EBBA1F82F16BF878FE274C735941      Anna J        AnnaJ250
# 1  4A830AD8B128F60AC02E83D6B6A530F7   QATAR2007       QATAR2007
# 2  AA2958C3E083861E81EEC085671BAA5B     aji1376         aji1376
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  jelinc2016      jelinc2016
# 4  DE02D713F209AEC684DC6108509E6912     VikaasK         VikaasK
#
#                                 name      id  \
# 0  InterContinental Paris - Le Grand  207742
# 1  InterContinental Paris - Le Grand  207742
# 2  InterContinental Paris - Le Grand  207742
# 3  InterContinental Paris - Le Grand  207742
# 4  InterContinental Paris - Le Grand  207742
#
#                                          description  rating  rating_count  \
# 0  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 1  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 2  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 3  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 4  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
#
#                                             features
# 0  ['roomFeatures_air conditioning', 'roomFeature...
# 1  ['roomFeatures_air conditioning', 'roomFeature...
# 2  ['roomFeatures_air conditioning', 'roomFeature...
# 3  ['roomFeatures_air conditioning', 'roomFeature...
# 4  ['roomFeatures_air conditioning', 'roomFeature...

# %%
df["combined"] = (
    "title: " + df.title.str.strip()+"; Content: " + df.text.str.strip()
    # +"; desc: "+ df.text.str.strip()
)

# %%
df.head()
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
#
#                           author_id author_name author_username  \
# 0  E488EBBA1F82F16BF878FE274C735941      Anna J        AnnaJ250
# 1  4A830AD8B128F60AC02E83D6B6A530F7   QATAR2007       QATAR2007
# 2  AA2958C3E083861E81EEC085671BAA5B     aji1376         aji1376
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  jelinc2016      jelinc2016
# 4  DE02D713F209AEC684DC6108509E6912     VikaasK         VikaasK
#
#                                 name      id  \
# 0  InterContinental Paris - Le Grand  207742
# 1  InterContinental Paris - Le Grand  207742
# 2  InterContinental Paris - Le Grand  207742
# 3  InterContinental Paris - Le Grand  207742
# 4  InterContinental Paris - Le Grand  207742
#
#                                          description  rating  rating_count  \
# 0  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 1  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 2  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 3  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 4  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
#
#                                             features  \
# 0  ['roomFeatures_air conditioning', 'roomFeature...
# 1  ['roomFeatures_air conditioning', 'roomFeature...
# 2  ['roomFeatures_air conditioning', 'roomFeature...
# 3  ['roomFeatures_air conditioning', 'roomFeature...
# 4  ['roomFeatures_air conditioning', 'roomFeature...
#
#                                             combined
# 0  title: A large impersonal place with an on tim...
# 1  title: Good hotel with rude waiter; Content: W...
# 2  title: Fantastic; Content: Absolutely top-notc...
# 3  title: Amidst the chaos of Fashion week, their...
# 4  title: Not worth the effort or money; Content:...

# %%
import re

df_combined = df.copy()

df_combined['combined'] = df_combined['combined'].apply(lambda x: re.sub('[^a-zA-z0-9\s]','',str(x)))

def lower_case(input_str):
    input_str = input_str.lower()
    return input_str

df_combined['combined']= df_combined['combined'].apply(lambda x: lower_case(x))

# %%
embedder = SentenceTransformer('all-mpnet-base-v2')
# Out:
# (…)851d5dd1af673670cdb299753/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# (…)1af673670cdb299753/1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (…)6e48e851d5dd1af673670cdb299753/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# (…)48e851d5dd1af673670cdb299753/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# (…)299753/config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# (…)1d5dd1af673670cdb299753/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# (…)73670cdb299753/sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# (…)f673670cdb299753/special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# (…)851d5dd1af673670cdb299753/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# (…)1af673670cdb299753/tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# (…)51d5dd1af673670cdb299753/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# (…)6e48e851d5dd1af673670cdb299753/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# (…)8e851d5dd1af673670cdb299753/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
import json
from sentence_transformers import SentenceTransformer, CrossEncoder, util
import gzip
import os
import torch

if not torch.cuda.is_available():
    print("Warning: No GPU found. Please add GPU to your notebook")
else:
  print("GPU Found!")
  embedder =  embedder.to('cuda')
# Out:
# GPU Found!

# %%
df_combined.head()
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
#
#                           author_id author_name author_username  \
# 0  E488EBBA1F82F16BF878FE274C735941      Anna J        AnnaJ250
# 1  4A830AD8B128F60AC02E83D6B6A530F7   QATAR2007       QATAR2007
# 2  AA2958C3E083861E81EEC085671BAA5B     aji1376         aji1376
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  jelinc2016      jelinc2016
# 4  DE02D713F209AEC684DC6108509E6912     VikaasK         VikaasK
#
#                                 name      id  \
# 0  InterContinental Paris - Le Grand  207742
# 1  InterContinental Paris - Le Grand  207742
# 2  InterContinental Paris - Le Grand  207742
# 3  InterContinental Paris - Le Grand  207742
# 4  InterContinental Paris - Le Grand  207742
#
#                                          description  rating  rating_count  \
# 0  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 1  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 2  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 3  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 4  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
#
#                                             features  \
# 0  ['roomFeatures_air conditioning', 'roomFeature...
# 1  ['roomFeatures_air conditioning', 'roomFeature...
# 2  ['roomFeatures_air conditioning', 'roomFeature...
# 3  ['roomFeatures_air conditioning', 'roomFeature...
# 4  ['roomFeatures_air conditioning', 'roomFeature...
#
#                                             combined
# 0  title a large impersonal place with an on time...
# 1  title good hotel with rude waiter content we w...
# 2  title fantastic content absolutely topnotch ro...
# 3  title amidst the chaos of fashion week their s...
# 4  title not worth the effort or money content th...

# %%
sample = df_combined[:10]

# %%
embedder =  embedder.to('cpu')

startTime = time.time()

sample["embedding"] = sample.combined.apply(lambda x: embedder.encode(x))

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Execution time in seconds: 4.553866147994995
# <ipython-input-20-e009c77fa025>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample["embedding"] = sample.combined.apply(lambda x: embedder.encode(x))

# %%
embedder =  embedder.to('cuda')
startTime = time.time()

sample["embedding"] = sample.combined.apply(lambda x: embedder.encode(x))

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Execution time in seconds: 0.25376367568969727
# <ipython-input-21-290f30ba95f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample["embedding"] = sample.combined.apply(lambda x: embedder.encode(x))

# %%
# from google.colab import drive
# drive.mount('/gdrive')

# %%
sample.to_pickle('/content/drive/MyDrive/Semantic_Search/df.pkl')    #to save the dataframe, df to 123.pkl

# %%
df_with_embedding = pd.read_pickle('/content/drive/MyDrive/Semantic_Search/df.pkl') #to load 123.pkl back to the dataframe df

# %%
df_with_embedding.embedding[0]

# %%
df_with_embedding.head()
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
#
#                           author_id author_name author_username  \
# 0  E488EBBA1F82F16BF878FE274C735941      Anna J        AnnaJ250
# 1  4A830AD8B128F60AC02E83D6B6A530F7   QATAR2007       QATAR2007
# 2  AA2958C3E083861E81EEC085671BAA5B     aji1376         aji1376
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  jelinc2016      jelinc2016
# 4  DE02D713F209AEC684DC6108509E6912     VikaasK         VikaasK
#
#                                 name      id  \
# 0  InterContinental Paris - Le Grand  207742
# 1  InterContinental Paris - Le Grand  207742
# 2  InterContinental Paris - Le Grand  207742
# 3  InterContinental Paris - Le Grand  207742
# 4  InterContinental Paris - Le Grand  207742
#
#                                          description  rating  rating_count  \
# 0  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 1  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 2  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 3  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 4  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
#
#                                             features  \
# 0  ['roomFeatures_air conditioning', 'roomFeature...
# 1  ['roomFeatures_air conditioning', 'roomFeature...
# 2  ['roomFeatures_air conditioning', 'roomFeature...
# 3  ['roomFeatures_air conditioning', 'roomFeature...
# 4  ['roomFeatures_air conditioning', 'roomFeature...
#
#                                             combined  \
# 0  title a large impersonal place with an on time...
# 1  title good hotel with rude waiter content we w...
# 2  title fantastic content absolutely topnotch ro...
# 3  title amidst the chaos of fashion week their s...
# 4  title not worth the effort or money content th...
#
#                                            embedding
# 0  [0.043491535, -0.012825324, 0.0029111414, 0.07...
# 1  [0.055250518, 0.019289263, -0.0056739766, 0.05...
# 2  [-0.014940904, 0.02296867, -0.003618411, 0.038...
# 3  [-0.0036499638, 0.042207047, -0.0062340726, 0....
# 4  [0.0013606999, -0.0038351996, 0.0018078145, 0....

# %%
query = 'Not worth the effort or money + This hotel is not worth the effort or the price'

query_embedding = embedder.encode(query,show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_with_embedding.combined[0]
# Out:
# 'title a large impersonal place with an on time check in problem and other issues content if you are looking for a huge grand hotel experience this place may be for you but i found it to be impersonal and the staff lacking warmth and sometimes manners they seem to avoid engagement with guests whenever possible add that to the fact that each morning and evening there are 2 or 3 bus loads of tour groups gathering in the lobby and right outside the hotel when i encountered this on my first evening and needed a taxi i asked the doorman whether he could get me a taxi or whether i should order an uber he simply nodded and walked away so i ordered an uber\n\nthe checkin counter must be understaffed as i had to wait in a long line for about 15 minutes only to be told that my room was not ready official checkin is 2pm but my room was not ready until 5pm i should have taken seriously the many previous tripadvisor reviewers who had the same experience they gave me a drink voucher in the bar as compensation but i didnt use it because i wasnt in the mood for a drink after international travel or any other day because im not a bar person and the checkin person said he would phone me when my room was ready but never did i only found out it was ready after checking\n\nthe breakfast buffet is fine but nothing special and over my 3 days there several times i bumped into servers who cut me off or crossed in front of me as i navigated to and from the buffet i had dinner in the restaurant straight from a long day of exploring and apparently didnt meet the maitre ds standards as he tried everything in his power to avoid seating me in the mostly empty restaurant at 615pm finally he phoned the front desk to verify that i was a hotel guest and ran out of excuses after all that trouble i found the menu limited the food mediocre and the service bordering on surly\n\nmy suite was large and nice although there was very low water pressure in the shower and oddly despite mirrors everywhere not one was full length also all of the glasses and coffee mugs in the minibar were dirty\n\nso one star for the decent room and for the two people working there who were genuinely nice to me during my 3 days there'

# %%
# corpus_embeddings = embedder.encode(df_with_embedding.combined,show_progress_bar=True)

# %%
# df_with_embedding['similarity']=cosine_similarity(corpus_embeddings, query_embedding)

# %%
df_with_embedding['similarity_2'] = df_with_embedding.embedding.apply(lambda x: cosine_similarity(x, query_embedding.reshape(768,-1)))

# %%
df_with_embedding
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
# 5  862073785  2022-09-26              4
# 6  861021031  2022-09-20              5
# 7  860421664  2022-09-16              5
# 8  856124006  2022-08-24              5
# 9  856016947  2022-08-23              5
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
# 5         Not quite up to Intercontinental standards
# 6                    Luxury in the heart of the city
# 7                                          Beautiful
# 8                Great old fashioned quality service
# 9          Best location and platform to visit Paris
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
# 5  We had a one night stay prior to taking the Eu...      0
# 6  We were very impressed with the intercontinent...      0
# 7  Visited for my birthday and everything was jus...      0
# 8  All I can say is we found good old fashioned f...      1
# 9  Our family of 4 plus a friend enjoyed the grea...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
# 5  /ShowUserReviews-g187147-d207742-r862073785-In...       en   MOBILE
# 6  /ShowUserReviews-g187147-d207742-r861021031-In...       en    OTHER
# 7  /ShowUserReviews-g187147-d207742-r860421664-In...       en    OTHER
# 8  /ShowUserReviews-g187147-d207742-r856124006-In...       en    OTHER
# 9  /ShowUserReviews-g187147-d207742-r856016947-In...       en   MOBILE
#
#                           author_id  ...                               name  \
# 0  E488EBBA1F82F16BF878FE274C735941  ...  InterContinental Paris - Le Grand
# 1  4A830AD8B128F60AC02E83D6B6A530F7  ...  InterContinental Paris - Le Grand
# 2  AA2958C3E083861E81EEC085671BAA5B  ...  InterContinental Paris - Le Grand
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  ...  InterContinental Paris - Le Grand
# 4  DE02D713F209AEC684DC6108509E6912  ...  InterContinental Paris - Le Grand
# 5  BA9F96090F35C7A562E550825BAB4B32  ...  InterContinental Paris - Le Grand
# 6  CB65D8DF04EEB78702BB03F39BAC6717  ...  InterContinental Paris - Le Grand
# 7  9D8328D86D62AFA560367B6F81565010  ...  InterContinental Paris - Le Grand
# 8  82C9562F2314BE52F0CD417EC6034CE2  ...  InterContinental Paris - Le Grand
# 9  266247D26801AA5B479974849CAA8210  ...  InterContinental Paris - Le Grand
#
#        id                                        description  rating  \
# 0  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 1  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 2  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 3  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 4  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 5  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 6  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 7  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 8  207742  The InterContinental Paris Le Grand, opened du...     4.5
# 9  207742  The InterContinental Paris Le Grand, opened du...     4.5
#
#   rating_count                                           features  \
# 0       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 1       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 2       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 3       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 4       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 5       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 6       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 7       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 8       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
# 9       3517.0  ['roomFeatures_air conditioning', 'roomFeature...
#
#                                             combined  \
# 0  title a large impersonal place with an on time...
# 1  title good hotel with rude waiter content we w...
# 2  title fantastic content absolutely topnotch ro...
# 3  title amidst the chaos of fashion week their s...
# 4  title not worth the effort or money content th...
# 5  title not quite up to intercontinental standar...
# 6  title luxury in the heart of the city content ...
# 7  title beautiful content visited for my birthda...
# 8  title great old fashioned quality service cont...
# 9  title best location and platform to visit pari...
#
#                                            embedding similarity  similarity_2
# 0  [0.043491535, -0.012825324, 0.0029111414, 0.07...   0.180471      [0.5707]
# 1  [0.055250518, 0.019289263, -0.0056739766, 0.05...   0.144596  [0.45725167]
# 2  [-0.014940904, 0.02296867, -0.003618411, 0.038...   0.154253   [0.4877919]
# 3  [-0.0036499638, 0.042207047, -0.0062340726, 0....   0.151105  [0.47783655]
# 4  [0.0013606999, -0.0038351996, 0.0018078145, 0....   0.255166  [0.80690473]
# 5  [0.041726083, 0.033815227, 0.001729757, 0.0653...   0.151502   [0.4790928]
# 6  [-0.04693219, -0.017643092, 0.024403231, 0.076...   0.105180  [0.33260918]
# 7  [0.0077629383, 0.033725727, 0.0060369275, 0.05...   0.146341  [0.46277204]
# 8  [0.026673276, -0.00047400966, 0.030833991, 0.0...   0.136536  [0.43176532]
# 9  [-0.043222655, -0.009725467, 0.0045521455, 0.0...   0.135314  [0.42790067]
#
# [10 rows x 22 columns]

# %%
# cosine_similarity(corpus_embeddings, query_embedding)

# %% [markdown]
# #Entire Data

# %%
startTime = time.time()

df_combined["embedding"] = df_combined.combined.apply(lambda x: embedder.encode(x))

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Execution time in seconds: 205.48085594177246

# %%
df_combined.to_pickle('/content/drive/MyDrive/Semantic_Search/entire_data.pkl')

# %% [markdown]
# ##Embedding upload

# %%
import pandas as pd
df = pd.read_pickle('/content/drive/MyDrive/Semantic_Search/entire_data.pkl') #to load 123.pkl back to the dataframe df

# %%
df.shape
# Out:
# (11990, 20)

# %%
df.head()
# Out:
#    review_id        date  review_rating  \
# 0  864290614  2022-10-12              1
# 1  864049819  2022-10-10              4
# 2  863952022  2022-10-10              5
# 3  863793066  2022-10-09              4
# 4  863631994  2022-10-08              2
#
#                                                title  \
# 0  A large impersonal place with an on time check...
# 1                        Good hotel with rude waiter
# 2                                          Fantastic
# 3  Amidst the chaos of Fashion week, their servic...
# 4                      Not worth the effort or money
#
#                                                 text  votes  \
# 0  If you are looking for a huge, grand hotel exp...      1
# 1  We went to this hotel just this month\nWe have...      1
# 2  Absolutely top-notch. Room, service, bed, pill...      0
# 3  We stayed during the Paris Fashion Week Chaos....      0
# 4  This hotel is not worth the effort or the pric...      0
#
#                                                  url language platform  \
# 0  /ShowUserReviews-g187147-d207742-r864290614-In...       en   MOBILE
# 1  /ShowUserReviews-g187147-d207742-r864049819-In...       en   MOBILE
# 2  /ShowUserReviews-g187147-d207742-r863952022-In...       en    OTHER
# 3  /ShowUserReviews-g187147-d207742-r863793066-In...       en   MOBILE
# 4  /ShowUserReviews-g187147-d207742-r863631994-In...       en   MOBILE
#
#                           author_id author_name author_username  \
# 0  E488EBBA1F82F16BF878FE274C735941      Anna J        AnnaJ250
# 1  4A830AD8B128F60AC02E83D6B6A530F7   QATAR2007       QATAR2007
# 2  AA2958C3E083861E81EEC085671BAA5B     aji1376         aji1376
# 3  DE4AB96DA3E104846D6D6423C2DAA4C8  jelinc2016      jelinc2016
# 4  DE02D713F209AEC684DC6108509E6912     VikaasK         VikaasK
#
#                                 name      id  \
# 0  InterContinental Paris - Le Grand  207742
# 1  InterContinental Paris - Le Grand  207742
# 2  InterContinental Paris - Le Grand  207742
# 3  InterContinental Paris - Le Grand  207742
# 4  InterContinental Paris - Le Grand  207742
#
#                                          description  rating  rating_count  \
# 0  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 1  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 2  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 3  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
# 4  The InterContinental Paris Le Grand, opened du...     4.5        3517.0
#
#                                             features  \
# 0  ['roomFeatures_air conditioning', 'roomFeature...
# 1  ['roomFeatures_air conditioning', 'roomFeature...
# 2  ['roomFeatures_air conditioning', 'roomFeature...
# 3  ['roomFeatures_air conditioning', 'roomFeature...
# 4  ['roomFeatures_air conditioning', 'roomFeature...
#
#                                             combined  \
# 0  title a large impersonal place with an on time...
# 1  title good hotel with rude waiter content we w...
# 2  title fantastic content absolutely topnotch ro...
# 3  title amidst the chaos of fashion week their s...
# 4  title not worth the effort or money content th...
#
#                                            embedding
# 0  [0.043491535, -0.012825324, 0.0029111414, 0.07...
# 1  [0.055250518, 0.019289263, -0.0056739766, 0.05...
# 2  [-0.014940904, 0.02296867, -0.003618411, 0.038...
# 3  [-0.0036499638, 0.042207047, -0.0062340726, 0....
# 4  [0.0013606999, -0.0038351996, 0.0018078145, 0....

# %%
# search through the reviews for a specific product
def search_reviews(df, query, n=5, pprint=True):
    query_embedding = embedder.encode(query,show_progress_bar=True)
    df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, query_embedding.reshape(768,-1)))

    results = (
        df.sort_values("similarity", ascending=False)
        .head(n))

    return results

# %%
query = 'close to Louvre and great food nearby but not too expensive'

# %%
results = search_reviews(df,query,15)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
results
# Out:
#        review_id        date  review_rating  \
# 15436  698261802  2019-08-12              5
# 10033  858737654  2022-09-06              4
# 14024  497037862  2017-06-28              5
# 28275  801368976  2021-08-02              5
# 16159  727252844  2019-11-18              5
# 6866   806790088  2021-08-28              5
# 207    834926510  2022-04-17              5
# 6233   227310602  2014-09-06              5
# 4933   815954462  2021-10-25              5
# 18833  840540236  2022-05-29              4
# 20535  743543812  2020-02-07              5
# 21898  839455495  2022-05-22              5
# 12729  825896939  2022-01-25              5
# 10912  860627748  2022-09-17              5
# 28578  735380549  2019-12-29              5
#
#                                                    title  \
# 15436                                         Recommend!
# 10033                    Great hotel close to the Louvre
# 14024  Fantastic Location and Service- Highly Recomme...
# 28275     Best location, elegant, clean and great rooms.
# 16159                      Perfect spot to explore Paris
# 6866           Nice small hotel at an excellent location
# 207                                  Best Paris Location
# 6233      Fantastic place, good value and well connected
# 4933                    Great location for romantic trip
# 18833                                    Great Locarion!
# 20535                                     Amazing Hotel!
# 21898       Wonderful boutique hotel close to the Louvre
# 12729                                Great place to stay
# 10912                                 Excellent location
# 28578                                 Excellent location
#
#                                                     text  votes  \
# 15436  Just minutes walk from the Louvre Museums and ...      2
# 10033  This was a great location with easy access to ...      1
# 14024  Best Location in Paris, 3 minutes walking dist...      0
# 28275  We spent 5 nights at the lovely Hotel Da Vinci...      1
# 16159  This was our first visit to Paris and stumbled...      1
# 6866   Clean, with a nice design and an excellent loc...      0
# 207    You can’t beat the location of this hotel! Rig...      0
# 6233   A real find; it's comfortable, quiet, and welc...      1
# 4933   Friendly staff. Great location, relaxed atmosp...      0
# 18833  Great location hotel near the louvre, shops, e...      1
# 20535  Great hotel so accommodating and very central ...      1
# 21898  A very nice hotel in a quiet plaza two blocks ...      0
# 12729  Wonderful location, near Notre Dame and Latin ...      0
# 10912  Excellent location, 10 minutes walking to Louv...      0
# 28578  Excellent location. You can walk to Louvre and...      1
#
#                                                      url language platform  \
# 15436  /ShowUserReviews-g187147-d197426-r698261802-Ci...       en   MOBILE
# 10033  /ShowUserReviews-g187147-d228694-r858737654-Ho...       en   MOBILE
# 14024  /ShowUserReviews-g187147-d197966-r497037862-Ho...       en    OTHER
# 28275  /ShowUserReviews-g187147-d6675948-r801368976-H...       en   MOBILE
# 16159  /ShowUserReviews-g187147-d635192-r727252844-Re...       en    OTHER
# 6866   /ShowUserReviews-g187147-d278169-r806790088-Ho...       en    OTHER
# 207    /ShowUserReviews-g187147-d228728-r834926510-Re...       en   MOBILE
# 6233   /ShowUserReviews-g187147-d613301-r227310602-A_...       en   MOBILE
# 4933   /ShowUserReviews-g187147-d228737-r815954462-Ho...       en    OTHER
# 18833  /ShowUserReviews-g187147-d587294-r840540236-Th...       en   MOBILE
# 20535  /ShowUserReviews-g187147-d207854-r743543812-Vi...       en   MOBILE
# 21898  /ShowUserReviews-g187147-d617625-r839455495-Gr...       en    OTHER
# 12729  /ShowUserReviews-g187147-d282186-r825896939-Ho...       en    OTHER
# 10912  /ShowUserReviews-g187147-d197424-r860627748-No...       en   MOBILE
# 28578  /ShowUserReviews-g187147-d236439-r735380549-Gr...       en    OTHER
#
#                               author_id  ...      author_username  \
# 15436  AA83C9E78CC6EC43EDC559DC7C0CDF57  ...  Loverofgoodfood1969
# 10033  107486993911F044C7A86C88BD8CBE6C  ...            kahnfeldt
# 14024  5271CD2C9F388D5BCE79D0F5598CC4FF  ...              Modhura
# 28275  1FEA86D03026BB83FEB43E29EA2B2D0D  ...          marydresser
# 16159  EDB7ED82C206CE0E8692D212CB2B4A4A  ...     AlexanderMeerkat
# 6866   3C6E94BBBCCA399CFE39851FEF397129  ...                do8yb
# 207    58EB5EA5E1A2FCD598F7F7F9D988306A  ...    Camper46227911888
# 6233   466D8F84569A260E4A3F39A32DDB3AC7  ...             bertiebr
# 4933   CD7F732341E1CB5D4414C9597B80B9C7  ...            jdN6106ZS
# 18833  542F0647332B2A98255FA48C0A7D840C  ...            abirmaher
# 20535  68F96329D3AFB1FE41F808711EB0BF6A  ...       meghanmK8531FG
# 21898  F68553597AC1CF5735AA52480B978199  ...         johnhR7616AX
# 12729  34FA5E075E65F727696A79CBAA8E2BB2  ...                liggy
# 10912  3E7EEE9C37BDA4982711F20CA32B8309  ...             difebalo
# 28578  7D3E0C71C35104D94E4A59739C4FFA23  ...         dgarci398912
#
#                                    name       id  \
# 15436        Citadines Les Halles Paris   197426
# 10033             Hotel Malte - Astotel   228694
# 14024            Hotel Folkestone Opera   197966
# 28275                    Hotel Da Vinci  6675948
# 16159  Residence & Spa Le Prince Regent   635192
# 6866              Hôtel Eugène en Ville   278169
# 207     Renaissance Paris Vendome Hotel   228728
# 6233                    A Room In Paris   613301
# 4933          Hôtel Trianon Rive Gauche   228737
# 18833        The Westin Paris - Vendôme   587294
# 20535                Villa Beaumarchais   207854
# 21898       Grand Hotel du Palais Royal   617625
# 12729        Hôtel Henri IV Rive Gauche   282186
# 10912          Novotel Paris Les Halles   197424
# 28578           Grand Hotel des Balcons   236439
#
#                                              description rating  rating_count  \
# 15436  Apart'hotel Citadines Les Halles welcomes you ...    4.0        1426.0
# 10033  Located in the 2nd district next to the Stock ...    5.0        2285.0
# 14024  Welcome to the Folkestone Opera Hotel, your Pa...    4.5         870.0
# 28275                                                NaN    NaN           NaN
# 16159  The Residence & Spa le Prince located in Saint...    4.5         471.0
# 6866                                                 NaN    NaN           NaN
# 207    Bask in the lavish lifestyle of our boutique h...    4.5        1618.0
# 6233   Right in the city centre of Paris 5 beautiful ...    4.5         237.0
# 4933                                                 NaN    NaN           NaN
# 18833                                                NaN    4.0        4438.0
# 20535                                                NaN    NaN           NaN
# 21898                                                NaN    NaN           NaN
# 12729  L’Hôtel Henri IV Rive Gauche vous invite à un ...    4.5         713.0
# 10912                                                NaN    NaN           NaN
# 28578  Located in the heart of the Saint Germain dist...    4.5         900.0
#
#                                                 features  \
# 15436  ['roomFeatures_blackout curtains', 'roomFeatur...
# 10033  ['roomFeatures_allergy-free room', 'roomFeatur...
# 14024  ['roomFeatures_blackout curtains', 'roomFeatur...
# 28275                                                NaN
# 16159  ['roomFeatures_air conditioning', 'roomFeature...
# 6866                                                 NaN
# 207    ['roomFeatures_bathrobes', 'roomFeatures_air c...
# 6233   ['roomFeatures_seating area', 'roomFeatures_ir...
# 4933                                                 NaN
# 18833  ['roomFeatures_bathrobes', 'roomFeatures_air c...
# 20535                                                NaN
# 21898                                                NaN
# 12729  ['roomFeatures_soundproof rooms', 'roomFeature...
# 10912                                                NaN
# 28578  ['roomFeatures_housekeeping', 'roomFeatures_pr...
#
#                                                 combined  \
# 15436  title recommend content just minutes walk from...
# 10033  title great hotel close to the louvre content ...
# 14024  title fantastic location and service highly re...
# 28275  title best location elegant clean and great ro...
# 16159  title perfect spot to explore paris content th...
# 6866   title nice small hotel at an excellent locatio...
# 207    title best paris location content you cant bea...
# 6233   title fantastic place good value and well conn...
# 4933   title great location for romantic trip content...
# 18833  title great locarion content great location ho...
# 20535  title amazing hotel content great hotel so acc...
# 21898  title wonderful boutique hotel close to the lo...
# 12729  title great place to stay content wonderful lo...
# 10912  title excellent location content excellent loc...
# 28578  title excellent location content excellent loc...
#
#                                                embedding    similarity
# 15436  [-0.021563573, 0.022654202, 0.0032279596, 0.06...    [0.762306]
# 10033  [0.005079792, 0.006933587, 0.0052261045, 0.046...   [0.7389945]
# 14024  [0.0051456545, 0.03332867, 0.009565785, 0.0622...   [0.7292296]
# 28275  [-0.04500476, 0.030609902, 0.0011573206, 0.069...   [0.7261322]
# 16159  [-0.039430726, 0.045125075, 0.009108206, 0.047...  [0.72453666]
# 6866   [-0.013086409, -0.022771467, 0.02151106, 0.072...  [0.71964693]
# 207    [-0.0070768404, -0.023154903, 0.011793142, 0.0...   [0.7182149]
# 6233   [-0.024605073, 0.00506499, 0.024327451, 0.0609...  [0.71735716]
# 4933   [-0.009349011, 0.06855302, 0.014361306, 0.0507...  [0.71603054]
# 18833  [0.0071857935, 0.026533479, 0.008893605, 0.057...   [0.7118777]
# 20535  [-0.015267877, 0.0006264779, 0.010793005, 0.03...   [0.7118212]
# 21898  [0.03218717, -0.01851448, 0.009698466, 0.05265...  [0.71097314]
# 12729  [-0.01611719, 0.055308603, 0.009837316, 0.0666...   [0.7075447]
# 10912  [-0.022658158, 0.042389695, 0.013877008, 0.037...   [0.7042279]
# 28578  [-0.002738802, 0.084232405, 0.003250452, 0.030...   [0.7023574]
#
# [15 rows x 21 columns]

# %%
# hlist = []
# for r in results.index:
#     if results.name[r] not in hlist:
#         smalldf = results.loc[results.name == results.name[r]]
#         print('Hotel name: {}'.format(results.name[r]))
#         print('Price per night: {}'.format(results.price_per_night.max()))
#         print('Description: {}'.format(results.description[r]))
#         print('Similarity Score: {}'.format(smalldf.similarity.max()))
#         print('Rating Score: {}'.format(smalldf.rating.max()))

#         print('\n')
#         print('Relevant Reviews:')
#         for s in smalldf.index:
#             print(smalldf.text[s])
#             print('\n')
#         print('xxx---xxx')
#         print('\n')
#         hlist.append(results.name[r])

# %%
# df_combined.shape[1]

# %%
# df = df_combined.copy()

# %% [markdown]
# Take all the reviews which are closest to the query, and groupby the hotel name

# %%
def search(query):
  n = 15
  query_embedding = embedder.encode(query)
  df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, query_embedding.reshape(768,-1)))

  results = (
      df.sort_values("similarity", ascending=False)
      .head(n))

  resultlist = []

  hlist = []
  for r in results.index:
      if results.name[r] not in hlist:
          smalldf = results.loc[results.name == results.name[r]]
          if smalldf.shape[1] > 3:
            smalldf = smalldf[:3]

          resultlist.append(
          {
            "name":results.name[r],
            "score": smalldf.similarity[r][0],
            "rating": smalldf.rating.max(),
            "relevant_reviews": [ smalldf.text[s] for s in smalldf.index]
          })
          hlist.append(results.name[r])
  return resultlist

# %%
search('close to Louvre and great food nearby but not too expensive')
# Out:
# [{'name': 'Citadines Les Halles Paris',
#   'score': 0.762306,
#   'rating': 4.0,
#   'relevant_reviews': ['Just minutes walk from the Louvre Museums and steps to all levels of dining establishments. Could not have been happier when we opened the door to our base rate room to find we had French doors opening to a little balcony with views to die for. It’s a busy city so if you want to be central there plenty of action outside but once the door was closed there was very little noise. Great to have a refrigerator/sink/cutlery/crockery/glassware. Really clean and modern place, fabulous find for the price bracket. Hotel has a laundry for guest use which is handy. Rooms are not serviced, which we liked - no need to prepare your personal items before staff arrive. Second visit and not my last. Staff at check in were excellent/English speaking and we purchased hop on hop off bus tickets there at a reduced price. ']},
#  {'name': 'Hotel Malte - Astotel',
#   'score': 0.7389945,
#   'rating': 5.0,
#   'relevant_reviews': ['This was a great location with easy access to several Metro stations, attractions, and restaurants.  It was great having snacks and drinks available all afternoon, especially since traveling with kids.  Good breakfast, and plenty of space for the 4 of us in the duplex room.  Having a second bathroom was very nice as well.']},
#  {'name': 'Hotel Folkestone Opera',
#   'score': 0.7292296,
#   'rating': 4.5,
#   'relevant_reviews': ['Best Location in Paris, 3 minutes walking distance to Opera Garnier and Gallery Lafayette and within walking distance to Louvre and Angelina and Place Vendome. Reasonably prices restaurants, deli, fromagerie,and daily supply stores on the same street.  Amazing, friendly staff, who are very helpful. super breakfast. They will call a cab for you any time in an instance. Clean , lovely, happy hotel recommended for anyone wishing to stay in a super, location, well connected to Metros, Pharmacies, and everything one needs. superb!!!']},
#  {'name': 'Hotel Da Vinci',
#   'score': 0.7261322,
#   'rating': nan,
#   'relevant_reviews': ['We spent 5 nights at the lovely Hotel Da Vinci, and recommend it highly. It is a small, elegant hotel. Fabulous staff were welcoming and extremely helpful. The room was in the back, so there was no view but that did not matter to us. The room was small but not confining, with a beautiful and comfortable large king sized bed, dressed in white bedding with real down pillows and comforter. We appreciated that as we hate the polyester bedding so many hotels use. The room was nicely cool with a quiet indiscrete air conditioner. We loved the bathroom, and the shower is a dream, great pressure, a huge rainshower head and a large shower stall. There were two nice closets, and good lighting.\nThe spa in the basement is a real treat, very magical and beautiful, and great to swim or soak, with a fantastic overhead jet to massage neck or back. \nBest of all, the location is perfect, two blocks to the Seine, the Louvre is right across the river, and a short couple of blocks to the heart of Saint Germain. Easy walking location but not in an overrun tourist location.']},
#  {'name': 'Residence & Spa Le Prince Regent',
#   'score': 0.72453666,
#   'rating': 4.5,
#   'relevant_reviews': ['This was our first visit to Paris and stumbled upon this apartment. There were 8 of us and it was perfect. Ideal location to visit most attractions. Lovely restaurants close by. \nA word of advice, don’t go to the small supermarket opposite the entrance very very expensive. Take a right & just up the hill on the first right you will find a better supermarket. Fresher produce and more variety. \nIt will take you around 15-20mins to walk to the Louvre & similar to the Notre Dame. \nWe would definitely stay here again and are already planning our return romantic trip for two. \n']},
#  {'name': 'Hôtel Eugène en Ville',
#   'score': 0.71964693,
#   'rating': nan,
#   'relevant_reviews': ["Clean, with a nice design and an excellent location. You're within a reasonable walking distance3 from Les Grands magasins and a nice walk awa from Le Louvre.\n\nDon't expect luxury, but you will get excellent quality for your money.\n\nVery comfortable beds."]},
#  {'name': 'Renaissance Paris Vendome Hotel',
#   'score': 0.7182149,
#   'rating': 4.5,
#   'relevant_reviews': ['You can’t beat the location of this hotel! Right near the Louvre,Tuileries, Rue St Honare. Wonderful welcome,terrific concierge assistance. Restaurant staff very helpful and efficient, lovely breakfast.\nExtremely comfortable room with all amenities, it is my first choice always in Paris!']},
#  {'name': 'A Room In Paris',
#   'score': 0.71735716,
#   'rating': 4.5,
#   'relevant_reviews': ["A real find; it's comfortable, quiet, and welcoming. About 200 metres from the Gare Du Nord, it's particularly convenient if you arrive on the Eurostar. We had the smallest room, but for €80 a night it was really good value. Peet was able to advise us on travel links (using the RER and metro from Gare Du Nord, and the 39 bus which goes to the Louvre), as well as preparing a lovely breakfast each morning. Will definitely be back. "]},
#  {'name': 'Hôtel Trianon Rive Gauche',
#   'score': 0.71603054,
#   'rating': nan,
#   'relevant_reviews': ['Friendly staff. Great location, relaxed atmosphere, 15 minute walk from Notre Dame and Louvre. Nice breakfast with fresh orange juice, viennoiserie, French cheese... Cosy room with a view. I can definitely recommend.']},
#  {'name': 'The Westin Paris - Vendôme',
#   'score': 0.7118777,
#   'rating': 4.0,
#   'relevant_reviews': ['Great location hotel near the louvre, shops, etc. rooms are nothing too special (at least the ones we stayed in) but great views if you face the street of the Eiffel Tower. Staff was very nice as well in our experience through our stay of a few nights.']},
#  {'name': 'Villa Beaumarchais',
#   'score': 0.7118212,
#   'rating': nan,
#   'relevant_reviews': ['Great hotel so accommodating and very central with lots of restaurants and the metro near by. The Louvre only a half hour walk away. Hotel itself is very clean and very pretty all the staff are very nice. Would definitely recommend!']},
#  {'name': 'Grand Hotel du Palais Royal',
#   'score': 0.71097314,
#   'rating': nan,
#   'relevant_reviews': ['A very nice hotel in a quiet plaza two blocks from the Louvre within walking distance of major attractions and great restaurant districts .  We stayed two nights on the 4th floor overlooking the courtyard.  The staff were incredibly friendly and helpful and the room clean and comfortable.']},
#  {'name': 'Hôtel Henri IV Rive Gauche',
#   'score': 0.7075447,
#   'rating': 4.5,
#   'relevant_reviews': ['Wonderful location, near Notre Dame and Latin Quarter. We could walk to the Louvre and Tivoli Gardens. Very nice spacious room for 3, with an affordable quality breakfast of crossaints and coffee and orange juice. Very nice atmosphere well decorated in boutique setting.']},
#  {'name': 'Novotel Paris Les Halles',
#   'score': 0.7042279,
#   'rating': nan,
#   'relevant_reviews': ['Excellent location, 10 minutes walking to Louvre and easy access to metro station. Breakfast has a great variety of food, rooms are comfortable. A great choice if you want to stay downtown Paris and visit the most remarkable museums of the city.']},
#  {'name': 'Grand Hotel des Balcons',
#   'score': 0.7023574,
#   'rating': 4.5,
#   'relevant_reviews': ['Excellent location. You can walk to Louvre and Notre Dame from there.The hotel is very nice and they can speak several lenguages. The rooms are clean and the breakfast is good. The best for me was the location']}]

# %% [markdown]
# #Building the API

# %%
import gradio as gr

def search(query):
  n = 15
  query_embedding = embedder.encode(query)
  df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, query_embedding.reshape(768,-1)))

  results = (
      df.sort_values("similarity", ascending=False)
      .head(n))

  resultlist = []

  hlist = []
  for r in results.index:
      if results.name[r] not in hlist:
          smalldf = results.loc[results.name == results.name[r]]
          smallarr = smalldf.similarity[r].max()
          sm =smalldf.rating[r].mean()

          if smalldf.shape[1] > 3:
            smalldf = smalldf[:3]

          resultlist.append(
          {
            "name":results.name[r],
            "description":results.description[r],
            "relevance score": smallarr.tolist(),
            "rating": sm.tolist(),
            "relevant_reviews": [ smalldf.text[s] for s in smalldf.index]
          })
          hlist.append(results.name[r])
  return resultlist

def greet(query):
    bm25 = search(query)
    return bm25

demo = gr.Interface(fn=greet, inputs="text", outputs="json")

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://bb0cbeb8a70ee0568a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://bb0cbeb8a70ee0568a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#

# %%
from gradio_client import Client

client = Client("https://3fba686d45d13ad493.gradio.live/")
result = client.predict(
				"Hotel near the Eiffel Tower!",	# str in 'query' Textbox component
				api_name="/predict"
)
print(result)
# Out:
# Loaded as API: https://3fba686d45d13ad493.gradio.live/ ✔
# [{'name': 'Hotel Duquesne Eiffel', 'description': 'This cosy hotel offers numerous advantages such as its geographic location, appreciated as much for "leisure" vacations as it is for business meetings. Between "les Invalides" and the Eiffel Tower, the Duquesne Eiffel Hotel is located in one of Paris\' most pleasant boroughs on the famous left bank of the Seine. The team welcomes you with a smile 24/7, while taking all the necessary measures to ensure that your stay is a pleasant one.', 'relevance score': 0.8061095476150513, 'rating': 4.5, 'relevant_reviews': ['The photos for this hotel do not do it justice. I have a front facing room with a view of the Eiffel Tower and it’s just spectacular for what it cost. You don’t need the Shangri La with this hotel. Very friendly staff with quick check in. I was supposed to be here with my husband but his passport didn’t have long enough (make sure you have at least 3 months if you’re coming from the UK) and they still sent up the champagne for our anniversary. Very clean and not as small as other reviewers have claimed. I 100% recommend this hotel, please don’t hesitate and treat yourself to a front facing room if you can.', 'We spent 5 nights here in early November and had a great stay.  Room was a good size with a nice bathroom, very clean.  We were lucky enough to have a bit of a view of the Eiffel Tower - a real bonus.  The breakfast had everything you could want to start your day.  Great location, about 5 minutes to École Militaire metro, rue Cler, Invalides and about 15 from Eiffel Tower, very walkable to Montparnasse and St Germain districts as well.   Staff were very helpful and very friendly, especially Christina (hope I got name right!).   I would stay here again and would highly recommend this hotel.', 'The location of this hotel couldn\'t be beat. We had the top corner room which had a window literally opening up on the Eiffel Tower with a wraparound balcony to boot. Exceptionally comfortable bed, walking distance to the Tower and a great neighborhood. I found this hotel using the search "Eiffel Tower" and "Balcony" and this couldn\'t have been more on point to meet that criteria.  Also the breakfast was quite good and a good range of available foods.']}, {'name': 'Hotel de la Paix Tour Eiffel', 'description': 'WELCOME TO THE HÔTEL DE LA PAIX TOUR EIFFEL The Hotel de la Paix Tour Eiffel welcomes you at the foot of the Eiffel Tower, in the 7th arrondissement of Paris. You will discover in a few steps the cultural wealth of Paris: The Trocadero, the Invalides, the Champs Elysees. Our fully refurbished three-star hotel, with a sober and contemporary design, with a warm and calm atmosphere, is a haven for both business and leisure travelers. Our inviting reception has a lounge with a comfortable sofa and armchairs, a library corner with a coffee and tea machine.', 'relevance score': 0.7902035117149353, 'rating': 4.5, 'relevant_reviews': ['Nice , but very small rooms and bathrooms, good breakfast, not noisy from the street, but you can hear your neighbour…..the distance to eiffeltower ist perfect, many restaurants in the surroundings. Perfect for a sightseeing weekend!', 'Modern, comfortable room on a charming street. Hotel staff very welcoming and helpful. Quick walk to the Eiffel Tower, many restaurants and metro stations. Big plus for me was the dark curtains that completely blocked out the sun in the morning!', "This was my last hotel of 5 that I stayed in on my solo trip to France.  \nThe location was EXCELLENT!  5 minute walk to the Eiffel Tower, including lots of places to eat and shop.\n10 minute walk to the Musee de L'Armee (their night show is amazing!) and Cafe L'Esplanade, as well as so many other popular placed.\nThere is staff 24 hours at the front desk.  They were all very friendly and helpful.\nThe breakfast was included with my stay and was Excellent! - yogurt, eggs, cheeses, meats, croissants, fruit, cakes, juices, hot chocolate, and more!\nMy room was tiny but  ...

# %%
result
# Out:
# [{'name': 'Hotel Duquesne Eiffel',
#   'description': 'This cosy hotel offers numerous advantages such as its geographic location, appreciated as much for "leisure" vacations as it is for business meetings. Between "les Invalides" and the Eiffel Tower, the Duquesne Eiffel Hotel is located in one of Paris\' most pleasant boroughs on the famous left bank of the Seine. The team welcomes you with a smile 24/7, while taking all the necessary measures to ensure that your stay is a pleasant one.',
#   'relevance score': 0.8061095476150513,
#   'rating': 4.5,
#   'relevant_reviews': ['The photos for this hotel do not do it justice. I have a front facing room with a view of the Eiffel Tower and it’s just spectacular for what it cost. You don’t need the Shangri La with this hotel. Very friendly staff with quick check in. I was supposed to be here with my husband but his passport didn’t have long enough (make sure you have at least 3 months if you’re coming from the UK) and they still sent up the champagne for our anniversary. Very clean and not as small as other reviewers have claimed. I 100% recommend this hotel, please don’t hesitate and treat yourself to a front facing room if you can.',
#    'We spent 5 nights here in early November and had a great stay.  Room was a good size with a nice bathroom, very clean.  We were lucky enough to have a bit of a view of the Eiffel Tower - a real bonus.  The breakfast had everything you could want to start your day.  Great location, about 5 minutes to École Militaire metro, rue Cler, Invalides and about 15 from Eiffel Tower, very walkable to Montparnasse and St Germain districts as well.   Staff were very helpful and very friendly, especially Christina (hope I got name right!).   I would stay here again and would highly recommend this hotel.',
#    'The location of this hotel couldn\'t be beat. We had the top corner room which had a window literally opening up on the Eiffel Tower with a wraparound balcony to boot. Exceptionally comfortable bed, walking distance to the Tower and a great neighborhood. I found this hotel using the search "Eiffel Tower" and "Balcony" and this couldn\'t have been more on point to meet that criteria.  Also the breakfast was quite good and a good range of available foods.']},
#  {'name': 'Hotel de la Paix Tour Eiffel',
#   'description': 'WELCOME TO THE HÔTEL DE LA PAIX TOUR EIFFEL The Hotel de la Paix Tour Eiffel welcomes you at the foot of the Eiffel Tower, in the 7th arrondissement of Paris. You will discover in a few steps the cultural wealth of Paris: The Trocadero, the Invalides, the Champs Elysees. Our fully refurbished three-star hotel, with a sober and contemporary design, with a warm and calm atmosphere, is a haven for both business and leisure travelers. Our inviting reception has a lounge with a comfortable sofa and armchairs, a library corner with a coffee and tea machine.',
#   'relevance score': 0.7902035117149353,
#   'rating': 4.5,
#   'relevant_reviews': ['Nice , but very small rooms and bathrooms, good breakfast, not noisy from the street, but you can hear your neighbour…..the distance to eiffeltower ist perfect, many restaurants in the surroundings. Perfect for a sightseeing weekend!',
#    'Modern, comfortable room on a charming street. Hotel staff very welcoming and helpful. Quick walk to the Eiffel Tower, many restaurants and metro stations. Big plus for me was the dark curtains that completely blocked out the sun in the morning!',
#    "This was my last hotel of 5 that I stayed in on my solo trip to France.  \nThe location was EXCELLENT!  5 minute walk to the Eiffel Tower, including lots of places to eat and shop.\n10 minute walk to the Musee de L'Armee (their night show is amazing!) and Cafe L'Esplanade, as well as so many other popular placed.\nThere is staff 24 hours at the front desk.  They were all very friendly and helpful.\nThe breakfast was included with my stay and was Excellent! - yogurt, eggs, cheeses, meats, croissants, fruit, cakes, juices, hot chocolate, and more!\nMy room was tiny but just right for me.  The bed was very comfortable, with lots of soft, fluffy pillows.\nThe bathroom was a bit of a tight fit, but very clean and modern.  There were no toiletries, but I had brought my own anyway.  Lots of towels which were thick and soft.\nTiny elevator (which I found in all the hotels in France), but I was on the 3rd floor and preferred to walk the spiral staircase.\nVery quiet - I did not hear any other guests at all (but did see them at breakfast, so it was not because it was empty - lol).\nAnd there is A/C which is very  important in the summer in Paris!\nI definitely recommend this hotel. :D"]},
#  {'name': 'Canopy By Hilton Paris Trocadero',
#   'description': None,
#   'relevance score': 0.7835427522659302,
#   'rating': None,
#   'relevant_reviews': ['Superb location just along the road from the Eiffel Tower. Very friendly and helpful team and a lovely room with a great view. Would highly recommend this hotel if you are looking for base to explore Paris from. Fantastic view from the sky bar on the top floor.']},
#  {'name': 'Hotel de Sers',
#   'description': None,
#   'relevance score': 0.78240966796875,
#   'rating': None,
#   'relevant_reviews': ['Boutique hotel with a contemporary charming decor, excellent money value and very close to the Champs Élysees and avenue Montaigne.\nMany rooms with balcony and Eiffeil Tower view. Nice restaurant.Nespresso machine and nice fitness. \n\n ']},
#  {'name': 'Relais 12bis B&B',
#   'description': 'Relais 12bis is a luxury Bed and Breakfast situated a few steps from the Eiffel Tower. Housed in a typical Parisian style building, Relais 12bis is at the crossroads between a Boutique Hotel and a family guesthouse. With 5 luxurious king-size bedrooms with en-suite bathrooms and its guest lounge, our B&B provides a five star service while experiencing an intimate and friendly atmosphere.',
#   'relevance score': 0.7816129922866821,
#   'rating': 5.0,
#   'relevant_reviews': ["It was my family of 6's first time in Paris. Travelled with my mom, aunt, sister, brother in law and their 2-year old. We booked 3 of their rooms for 4 nights. The owner Philippe and his wife, son Leon were excellent hosts.  Beautiful historic building, upgraded rooms even better than it looks in the pictures! Loved everything about it- rooms, bathrooms and beds were so comfortable and had daily housekeeping services. The breakfasts every morning were homemade- OJ, jams, eggs, toast, cold cuts, artisan cheeses and best selection of French teas and coffee. 5 minute walk to the Eiffel tower, restaurants, subway/trains, city bus tours. It was a dream trip, very memorable, would highly recommend this place! "]},
#  {'name': 'Le Derby Alma',
#   'description': "Le Derby Alma is an excellent choice for travelers visiting Paris, offering a boutique environment alongside many helpful amenities designed to enhance your stay.\nWhile staying at Best Western Paris, visitors can check out Louvre Museum (1.6 mi) and Cathédrale Notre-Dame de Paris (2.3 mi), some of Paris' top attractions.\nBest Western Paris offers guests an array of room amenities including a flat screen TV, air conditioning, and a minibar, and getting online is possible, as free wifi is available.\nThe hotel offers a 24 hour front desk, room service, and a concierge, to make your visit even more pleasant. The property also features a lounge.\nWhile you’re here, be sure to check out some of the wine bars, including L'Avant Comptoir, Freddy's, and Les Epiciers, all of which are a short distance from Le Derby Alma.\nBest of all, Le Derby Alma makes it easy to experience many great Paris attractions like Luxembourg Gardens, Parc Monceau, and Esplanade des Invalides, which are some popular parks.\nEnjoy your stay in Paris!\n",
#   'relevance score': 0.7746119499206543,
#   'rating': 4.5,
#   'relevant_reviews': ['Staff extremely friendly, helpful, and professional , especially Mayowa. The rooms are very clean, and a great location, easy to access cabs and scooters. It is near the Eiffel Tower. The hotel sits on a busy but quiet street and many cafés that are open late.']},
#  {'name': 'Sonder Atala Champs-Élysées',
#   'description': "Steps from the Champs-Élysées, welcome to your Parisian pied-à-terre. The art-deco exterior of Atala sets the scene for your “city of love” stay. Local contemporary art lines the colorful lobby walls inside. The marble-floored lounge and leafy courtyard are comfortable spots for unwinding. And the gym has plenty of equipment for a daily workout. Each thoughtfully-designed space includes a coffee maker and standard cable. Plus, you can enjoy complimentary breakfast every morning. In this iconic neighborhood, there's plenty for you to explore. The best of the city’s luxury shopping is around the corner. The Arc de Triomphe has sweeping views from the Eiffel Tower to the Sacré Coeur. Palais de Tokyo nearby hosts spectacular art exhibitions and events. You can catch the metro from George V station to discover the rest of the magical French capital. Whatever your plans in Paris, the itinerary starts at Atala. You may encounter noise from the surrounding area and from construction.",
#   'relevance score': 0.7735867500305176,
#   'rating': 4.5,
#   'relevant_reviews': ['The hotel is really easy to get to from CDG airport, located just behind the Champ Elysees, a short walk to the main shopping trip and metro, though i would recommend walking or taking the electric scooters everywhere! \nStaff were very friendly from the start, the gentleman that was on site in the evening was extremely friendly, offering me and my boyfriend a free glass of wine and snacks while we were in the lounge enjoying a game of chess. A lovely touch. \nOnce you get through the slightly dated internal hallway of your room, the main area is spacious and clean. Bathroom is a good size with great pressure in the shower. \nWould definitely recommend the hotel, and try to ask for a room with a view. We were on the 6th floor with a balcony that overlooked the top of the Eiffel Tower!',
#    '4 night stay at this hotel.Strategic place for tourist. Its nearby just a few mins walk distance to shopping district and metro station.A very safe surrounding.The staff are helpful and the room is clean but a bit small.The best was the hotel reception staff offered us both to stay at the top of hotel.From there we can see a magnificent day and night view of entire city of Paris and iconic Eiffel tower!']},
#  {'name': 'Hotel Les Matins de Paris & Spa',
#   'description': None,
#   'relevance score': 0.7713812589645386,
#   'rating': None,
#   'relevant_reviews': ['We stayed here in November 2018 for our anniversary. Even though where it is, it is still easy to access all over Paris.\n\nWe did the hop on hop off bus and was about a 15 minute walk to the stop which was nice as we past all the french cafes and shops. From there we got all around Paris and at the end of the day wasn’t a big hike to get back to the hotel.\n\nThe room was immaculate and so stylish, not anything we ever imagined. The room even had a bath so we took advantage of that! The view from the room was a little disappointing as it faced a courtyard but if we every returned we would book for a view of the Eiffel Tower.\n\nWe ordered room service one night which came within half an house and was GORGEOUS lasagne! We even spent a night chilling in bed and watching tv just to take in the room and our stay. \n\nThe staff was a huge help especially with recommending restaurants and directing us the best way to the station and bus stops.\n\nThe is also a pool although we didn’t go to it, it looks nice and clean perfect for a morning swim.\n\nAll in all, I would definitely stay here again the location is great within 1 minute you have at least 10 shops restaurants, seafood shops and shops that sell wine for €3 which we could get enough of! My partner proposed to me whilst we was in Paris (at the Eiffel Tower) so this hotel holds very special memories for us! \n\nPerfect for couples looking for a romantic getaway! \n\nThank you so much Les matins! ']},
#  {'name': 'Citadines Tour Eiffel Paris',
#   'description': "Finding an ideal family-friendly hotel in Paris does not have to be difficult. Welcome to Citadines Tour Eiffel Paris, a nice option for travelers like you.\nClose to some of Paris' most popular landmarks, such as Champs-Elysees (1.5 mi) and Arc de Triomphe (1.7 mi), Citadines Tour Eiffel Paris is a great destination for tourists.\nCitadines Tour Eiffel Paris is a family-friendly hotel offering a flat screen TV, air conditioning, and a refrigerator in the rooms, and it is easy to stay connected during your stay as free wifi is offered to guests.\nThe hotel features a 24 hour front desk, a concierge, and baggage storage. Plus, guests can enjoy breakfast, which has made this a popular choice among travelers visiting Paris. For guests with a vehicle, parking is available.\nWhile in Paris be sure to experience local filet mignon favorites at L'Avenue, Le Ciel de Paris, or Monsieur Bleu.\nIf you’re looking for something to do, Eiffel Tower (0.7 mi) and Trocadero (1.0 mi) are a nice way to spend some time, and they are all within walking distance of Citadines Tour Eiffel Hotel.\nCitadines Tour Eiffel Paris looks forward to welcoming you on your visit to Paris.\n",
#   'relevance score': 0.7700664401054382,
#   'rating': 4.5,
#   'relevant_reviews': ['Very comfortable and cozy hotel near Effel Tower. If you want to have a good rest with sigtseeing, I wold reccomend you this hotel. There are cozy rooms with small kitchen full of equipment, good bathroom, clean towels and bed linen. It is very easy to go to different famous places from the hotel']},
#  {'name': 'Renaissance Paris Nobel Tour Eiffel Hotel',
#   'description': None,
#   'relevance score': 0.7678737640380859,
#   'rating': None,
#   'relevant_reviews': ['Nice rooms with  garden as well as views of the Eiffel Tower. The rooms were nice size but we were there during the record heat wave and the airconditioning was not able to adequately cool the rooms. The staff was excellent  and did a wonderful job of getting us booked in. Breakfast  buffet had a lot of offerings but I cannot comment on the cost since it was complimentary because of my status with Marriott. We never got to use the bar(it was small) as it closed before we got back to the hotel after exploring for the day. Hotel is easy walking distance to Eiffel Tower, Arc De Triomphe and Champs Elysees. There are numerous restaurants in easy walking distance of the hotel. We found using Uber to be the easiest way to get to places we wanted to explore.']}]

# %%
# !cat /tmp/gradio/tmp0pxsbxyh.json
# Out:
# [{"name": "Hotel Duquesne Eiffel", "description": "This cosy hotel offers numerous advantages such as its geographic location, appreciated as much for \"leisure\" vacations as it is for business meetings. Between \"les Invalides\" and the Eiffel Tower, the Duquesne Eiffel Hotel is located in one of Paris' most pleasant boroughs on the famous left bank of the Seine. The team welcomes you with a smile 24/7, while taking all the necessary measures to ensure that your stay is a pleasant one.", "relevance score": 0.8061095476150513, "rating": 4.5, "relevant_reviews": ["The photos for this hotel do not do it justice. I have a front facing room with a view of the Eiffel Tower and it\u2019s just spectacular for what it cost. You don\u2019t need the Shangri La with this hotel. Very friendly staff with quick check in. I was supposed to be here with my husband but his passport didn\u2019t have long enough (make sure you have at least 3 months if you\u2019re coming from the UK) and they still sent up the champagne for our anniversary. Very clean and not as small as other reviewers have claimed. I 100% recommend this hotel, please don\u2019t hesitate and treat yourself to a front facing room if you can.", "We spent 5 nights here in early November and had a great stay.  Room was a good size with a nice bathroom, very clean.  We were lucky enough to have a bit of a view of the Eiffel Tower - a real bonus.  The breakfast had everything you could want to start your day.  Great location, about 5 minutes to \u00c9cole Militaire metro, rue Cler, Invalides and about 15 from Eiffel Tower, very walkable to Montparnasse and St Germain districts as well.   Staff were very helpful and very friendly, especially Christina (hope I got name right!).   I would stay here again and would highly recommend this hotel.", "The location of this hotel couldn't be beat. We had the top corner room which had a window literally opening up on the Eiffel Tower with a wraparound balcony to boot. Exceptionally comfortable bed, walking distance to the Tower and a great neighborhood. I found this hotel using the search \"Eiffel Tower\" and \"Balcony\" and this couldn't have been more on point to meet that criteria.  Also the breakfast was quite good and a good range of available foods."]}, {"name": "Hotel de la Paix Tour Eiffel", "description": "WELCOME TO THE H\u00d4TEL DE LA PAIX TOUR EIFFEL The Hotel de la Paix Tour Eiffel welcomes you at the foot of the Eiffel Tower, in the 7th arrondissement of Paris. You will discover in a few steps the cultural wealth of Paris: The Trocadero, the Invalides, the Champs Elysees. Our fully refurbished three-star hotel, with a sober and contemporary design, with a warm and calm atmosphere, is a haven for both business and leisure travelers. Our inviting reception has a lounge with a comfortable sofa and armchairs, a library corner with a coffee and tea machine.", "relevance score": 0.7902035117149353, "rating": 4.5, "relevant_reviews": ["Nice , but very small rooms and bathrooms, good breakfast, not noisy from the street, but you can hear your neighbour\u2026..the distance to eiffeltower ist perfect, many restaurants in the surroundings. Perfect for a sightseeing weekend!", "Modern, comfortable room on a charming street. Hotel staff very welcoming and helpful. Quick walk to the Eiffel Tower, many restaurants and metro stations. Big plus for me was the dark curtains that completely blocked out the sun in the morning!", "This was my last hotel of 5 that I stayed in on my solo trip to France.  \nThe location was EXCELLENT!  5 minute walk to the Eiffel Tower, including lots of places to eat and shop.\n10 minute walk to the Musee de L'Armee (their night show is amazing!) and Cafe L'Esplanade, as well as so many other popular placed.\nThere is staff 24 hours at the front desk.  They were all very friendly and helpful.\nThe breakfast was included with my stay and was Excellent! - yogurt, eggs, cheeses, meats, croissants, fruit, cakes, juices, ho ...
